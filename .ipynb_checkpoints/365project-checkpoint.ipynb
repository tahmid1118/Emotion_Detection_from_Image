# %%
#Tahmid Shahriar Bhuiyan     ID: 2017-3-60-009(Sec 3)
#Mahedi Hassan Ratul          ID: 2017-3-60-050(Sec 4)

import tensorflow as tf             #TensorFlow is an open source library for numerical computation and large-scale machine learning. TensorFlow bundles together a slew of machine learning and deep learning (aka neural networking) models and algorithms and makes them useful by way of a common metaphor.
import matplotlib.pyplot as plt     #creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels
import zipfile                      
import cv2                          #processes image
import os                           #provides functions for interacting with the operating system
import numpy as np                  #works with arrays
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import ImageDataGenerator #labels images
from tensorflow.keras.preprocessing import image
from playsound import playsound #plays audio

# %%
img = image.load_img("train/happy/2.jpg")

# %%
plt.imshow(img)

# %%
cv2.imread("train/happy/2.jpg").shape    #shape of 3D array
# Out:
# (361, 378, 3)

# %%
train_datagen = ImageDataGenerator(rescale=1/255)           #dataset generation & normalization
validation_datagen = ImageDataGenerator(rescale=1/255)

# %%
train_generator = train_datagen.flow_from_directory(
        'train',  # This is the source directory for training images
        target_size=(200, 200),  # All images will be resized to 200x200
        batch_size=128,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 1217 images belonging to 2 classes.

# %%
validation_generator = train_datagen.flow_from_directory(
        'validation/',  # This is the source directory for training images
        target_size=(200, 200),  # All images will be resized to 150x150
        batch_size=128,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 1222 images belonging to 2 classes.

# %%
train_generator.class_indices #see generated labels
# Out:
# {'happy': 0, 'not_happy': 1}

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(200, 200, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    #tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    #tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    #tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    #tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), # converts into 1D array
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'), #connects all layers
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
from tensorflow.keras.optimizers import RMSprop # optimizes the model and sets learning rate

# %%
model.compile(loss='binary_crossentropy', #determines loss
              optimizer=RMSprop(lr=0.0001),
              metrics=['accuracy'])

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(lr=0.0001),
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=5,  
      epochs=30,
      validation_data = validation_generator) #train the model with inputs
# Out:
# Epoch 1/30
# 5/5 [==============================] - 9s 2s/step - loss: 0.7614 - accuracy: 0.7781 - val_loss: 0.4444 - val_accuracy: 0.8282
# Epoch 2/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.4402 - accuracy: 0.8284 - val_loss: 0.4507 - val_accuracy: 0.8282
# Epoch 3/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.4377 - accuracy: 0.8359 - val_loss: 0.3748 - val_accuracy: 0.8282
# Epoch 4/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.4093 - accuracy: 0.8371 - val_loss: 0.3788 - val_accuracy: 0.8282
# Epoch 5/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.3179 - accuracy: 0.8769 - val_loss: 0.5472 - val_accuracy: 0.8282
# Epoch 6/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.3607 - accuracy: 0.8648 - val_loss: 0.2923 - val_accuracy: 0.9092
# Epoch 7/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.3986 - accuracy: 0.8596 - val_loss: 0.2642 - val_accuracy: 0.8887
# Epoch 8/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.2816 - accuracy: 0.8766 - val_loss: 0.3544 - val_accuracy: 0.9337
# Epoch 9/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.2939 - accuracy: 0.8908 - val_loss: 0.2940 - val_accuracy: 0.8527
# Epoch 10/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.2283 - accuracy: 0.9125 - val_loss: 0.2231 - val_accuracy: 0.9452
# Epoch 11/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.2517 - accuracy: 0.9133 - val_loss: 0.2367 - val_accuracy: 0.8773
# Epoch 12/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.2764 - accuracy: 0.8922 - val_loss: 0.1932 - val_accuracy: 0.9264
# Epoch 13/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1856 - accuracy: 0.9391 - val_loss: 0.1801 - val_accuracy: 0.9190
# Epoch 14/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.2139 - accuracy: 0.9272 - val_loss: 0.2628 - val_accuracy: 0.9403
# Epoch 15/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.2392 - accuracy: 0.9185 - val_loss: 0.1550 - val_accuracy: 0.9427
# Epoch 16/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.1340 - accuracy: 0.9549 - val_loss: 0.2139 - val_accuracy: 0.9534
# Epoch 17/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1766 - accuracy: 0.9453 - val_loss: 0.3917 - val_accuracy: 0.8380
# Epoch 18/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.2496 - accuracy: 0.9078 - val_loss: 0.1324 - val_accuracy: 0.9640
# Epoch 19/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.1309 - accuracy: 0.9549 - val_loss: 0.1244 - val_accuracy: 0.9697
# Epoch 20/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1551 - accuracy: 0.9422 - val_loss: 0.1185 - val_accuracy: 0.9607
# Epoch 21/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1287 - accuracy: 0.9515 - val_loss: 0.1622 - val_accuracy: 0.9632
# Epoch 22/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1827 - accuracy: 0.9497 - val_loss: 0.1941 - val_accuracy: 0.9116
# Epoch 23/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1394 - accuracy: 0.9578 - val_loss: 0.1274 - val_accuracy: 0.9714
# Epoch 24/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.1228 - accuracy: 0.9584 - val_loss: 0.1035 - val_accuracy: 0.9755
# Epoch 25/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1036 - accuracy: 0.9688 - val_loss: 0.1049 - val_accuracy: 0.9583
# Epoch 26/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1008 - accuracy: 0.9672 - val_loss: 0.0861 - val_accuracy: 0.9722
# Epoch 27/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.1427 - accuracy: 0.9484 - val_loss: 0.0940 - val_accuracy: 0.9632
# Epoch 28/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.0639 - accuracy: 0.9809 - val_loss: 0.0815 - val_accuracy: 0.9705
# Epoch 29/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.0788 - accuracy: 0.9740 - val_loss: 0.0915 - val_accuracy: 0.9640
# Epoch 30/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.0743 - accuracy: 0.9740 - val_loss: 0.0883 - val_accuracy: 0.9640

# %%
import tensorflow as tf             #TensorFlow is an open source library for numerical computation and large-scale machine learning. TensorFlow bundles together a slew of machine learning and deep learning (aka neural networking) models and algorithms and makes them useful by way of a common metaphor.
import matplotlib.pyplot as plt     #creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels
import zipfile                      
import cv2                          #processes image
import os                           #provides functions for interacting with the operating system
import numpy as np                  #works with arrays
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import ImageDataGenerator #labels images
from tensorflow.keras.preprocessing import image
from playsound import playsound #plays audio
dir_path = "test"
for i in os.listdir(dir_path):
    img = image.load_img(dir_path+ '//' + i , target_size=(200, 200))
    plt.imshow(img)
    plt.show()
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    images = np.vstack([x])

    classes =model.predict(images)
    if classes[0]==0:
        playsound("happy.wav")
        print("You are happy")
 
    else:
        playsound("sad.wav")
        print("you are sad")
# Out:
# you are sad
# you are sad
